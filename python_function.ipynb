# %% [markdown]
# <a href="https://colab.research.google.com/github/mayaannkkk/PythonSeries/blob/main/python_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_even(i):
  if i % 2 ==0:
    return True
  else:
    return False

# %%
is_even(100)
# Out:
# True

# %% [markdown]
# # Without return statement

# %%
def is_even(i):
  if i % 2 ==0:
    print('True')
  else:
    print('False')

# %%
is_even(33)
# Out:
# False

# %%
L =[1,2,3]
print(L.append(4))
# Out:
# None

# %%
def f():
  def x(a,b):
    return a+b
  return x

val = f()(3,4)
print(val)
# Out:
# 7

# %%
def func_a():
  print("inside func a")
def func_b(z):
  print("inside func b")
  return z

print(func_b(func_a))
# Out:
# inside func b
# <function func_a at 0x7c5b372a9ee0>

# %%
# chech is a string has a

a = lambda s :"a" in s

# %%
a("hia")
# Out:
# True

# %%
a = lambda x :"even" if  x % 2 ==0 else "odd"

# %%
a(6)
# Out:
# 'even'

# %%
l =[1,2,3,4,5,6]

def transform(f,l):
  out = []
  for i in l:
    out.append(f(i))

  print(out)
transform(lambda x : x**2, l)
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
list(map(lambda x : x**2,[2,3,4,5]))
# Out:
# [4, 9, 16, 25]

# %%
#odd/even labeling of list item

list(map(lambda x : "even" if x %2 ==0 else "odd",[12,2,3,4,56,7]))
# Out:
# ['even', 'even', 'odd', 'even', 'even', 'odd']

# %%
list(filter(lambda fruits : "a" in fruits,["apple","dasda","sdsf"]))
# Out:
# ['apple', 'dasda']

# %%
import functools

functools.reduce(lambda x,y : x+y,[1,2,3,4,5])
# Out:
# 15
