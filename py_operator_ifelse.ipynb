# %% [markdown]
# <a href="https://colab.research.google.com/github/mayaannkkk/PythonSeries/blob/main/py_operator_ifelse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(5//2)
# Out:
# 2

# %%
print(5%2)
# Out:
# 1

# %%
print (1==4 and 2==2)
print (1==4 or 2==2)
# Out:
# False
# True

# %%
print(2 ^ 3)
# Out:
# 1

# %%
print("D" in "Delhi")
print("D" not in "Delhi")
# Out:
# True
# False

# %%
num = int(input("Enter a num:"))

while num != 0:
  last_d = num % 10
  print(last_d)
  num //= 10
# Out:
# Enter a num:234
# 4
# 3
# 2

# %%
#Menu based progrma

Menu = """ Hi please enter your query:
Press 1 for payment
Press 2 for balance
Press 3 for withdrawl
Press 4 for reset
"""
num = int(input("Enter number:"))
if num == 1:
  print("Payment")
elif num == 2:
  print("balance")
elif num == 3:
  print("withdrawl")
else :
  print('reset')
# Out:
# Enter number:4
# reset

# %%
# table

i = 1

while i <= 10:
  print ( f" {i} * 2 = {i * 2}")
  i +=1
# Out:
#  1 * 2 = 2
#  2 * 2 = 4
#  3 * 2 = 6
#  4 * 2 = 8
#  5 * 2 = 10
#  6 * 2 = 12
#  7 * 2 = 14
#  8 * 2 = 16
#  9 * 2 = 18
#  10 * 2 = 20
