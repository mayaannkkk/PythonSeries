# %% [markdown]
# <a href="https://colab.research.google.com/github/mayaannkkk/PythonSeries/blob/main/python_strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "Hello World"

# %%
s.capitalize()
# Out:
# 'Hello world'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s.lower()
# Out:
# 'hello world'

# %%
s.swapcase()
# Out:
# 'hELLO wORLD'

# %%
name = "mayank"

gen = "male"
"hi my name is {} and i am a {}".format(name,gen)
# Out:
# 'hi my name is mayank and i am a male'

# %%
"hi my name is mayank".split()
# Out:
# ['hi', 'my', 'name', 'is', 'mayank']

# %%
" ".join(['hi', 'my', 'name', 'is', 'mayank'])
# Out:
# 'hi my name is mayank'

# %%
"hi                          ".strip()
# Out:
# 'hi'

# %%
"hi my name is mayank".replace("mayank","kanyam")
# Out:
# 'hi my name is kanyam'
